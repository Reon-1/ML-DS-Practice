# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Importing the datasets

npl_data = pd.read_csv('/Projects/ML_AI Prac/Nepal_HDI.csv')

# %%
# Basic Overview for the datasets
npl_data.head()
# Out:
#     country_code   country_name   indicator_id  \
# 0  #country+code  #country+name  #indicator+id
# 1            NPL          Nepal            abr
# 2            NPL          Nepal            abr
# 3            NPL          Nepal            abr
# 4            NPL          Nepal            abr
#
#                                       indicator_name   index_id  \
# 0                                    #indicator+name  #index+id
# 1  Adolescent Birth Rate (births per 1,000 women ...        GII
# 2  Adolescent Birth Rate (births per 1,000 women ...        GII
# 3  Adolescent Birth Rate (births per 1,000 women ...        GII
# 4  Adolescent Birth Rate (births per 1,000 women ...        GII
#
#                 index_name                 value        year
# 0              #index+name  #indicator+value+num  #date+year
# 1  Gender Inequality Index               134.737        1990
# 2  Gender Inequality Index               132.557        1991
# ...

# %%
npl_data.describe()
# Out:
#        country_code country_name indicator_id  \
# count           978          978          978
# unique            2            2           47
# top             NPL        Nepal          abr
# freq            977          977           34
#
#                                            indicator_name index_id  \
# count                                                 978      978
# unique                                                 47        8
# top     Adolescent Birth Rate (births per 1,000 women ...      GDI
# freq                                                   34      341
#
#                       index_name   value  year
# count                        978     978   978
# unique                         8     886    35
# top     Gender Development Index  31.913  2019
# freq                         341      13    42

# %%
npl_data.mean(numeric_only=True)
# Out:
# Series([], dtype: float64)

# %%
npl_data.head(25)
# Out:
#      country_code   country_name   indicator_id  \
# 0   #country+code  #country+name  #indicator+id
# 1             NPL          Nepal            abr
# 2             NPL          Nepal            abr
# 3             NPL          Nepal            abr
# 4             NPL          Nepal            abr
# 5             NPL          Nepal            abr
# 6             NPL          Nepal            abr
# 7             NPL          Nepal            abr
# 8             NPL          Nepal            abr
# 9             NPL          Nepal            abr
# 10            NPL          Nepal            abr
# 11            NPL          Nepal            abr
# 12            NPL          Nepal            abr
# 13            NPL          Nepal            abr
# 14            NPL          Nepal            abr
# 15            NPL          Nepal            abr
# 16            NPL          Nepal            abr
# 17            NPL          Nepal            abr
# ...

# %%
npl_data.loc[5]
# Out:
# country_code                                                    NPL
# country_name                                                  Nepal
# indicator_id                                                    abr
# indicator_name    Adolescent Birth Rate (births per 1,000 women ...
# index_id                                                        GII
# index_name                                  Gender Inequality Index
# value                                                       135.082
# year                                                           1994
# Name: 5, dtype: object

# %%
pd.crosstab(npl_data['year'],npl_data['value'])
# Out:
# value       #indicator+value+num  0.037  0.051  0.06  0.066  0.074  0.085  \
# year
# #date+year                     1      0      0     0      0      0      0
# 1990                           0      1      0     0      0      0      0
# 1991                           0      0      1     0      0      0      0
# 1992                           0      0      0     1      0      0      0
# 1993                           0      0      0     0      1      0      0
# 1994                           0      0      0     0      0      1      0
# 1995                           0      0      0     0      0      0      0
# 1996                           0      0      0     0      0      0      0
# 1997                           0      0      0     0      0      0      0
# 1998                           0      0      0     0      0      0      0
# 1999                           0      0      0     0      0      0      0
# 2000                           0      0      0     0      0      0      0
# ...

# %%
npl_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 978 entries, 0 to 977
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   country_code    978 non-null    object
#  1   country_name    978 non-null    object
#  2   indicator_id    978 non-null    object
#  3   indicator_name  978 non-null    object
#  4   index_id        978 non-null    object
#  5   index_name      978 non-null    object
#  6   value           978 non-null    object
#  7   year            978 non-null    object
# dtypes: object(8)
# memory usage: 61.2+ KB

# %%
# Cleaning any Null values

npl_data.isnull().sum()
# Out:
# country_code      0
# country_name      0
# indicator_id      0
# indicator_name    0
# index_id          0
# index_name        0
# value             0
# year              0
# dtype: int64

# %%
npl_data.duplicated().sum()
# Out:
# np.int64(0)

# %%
npl_data[npl_data['indicator_name'].str.contains('HDI', case=False)]
# Out:
#     country_code country_name       indicator_id  \
# 88           NPL        Nepal      diff_hdi_phdi
# 89           NPL        Nepal      diff_hdi_phdi
# 90           NPL        Nepal      diff_hdi_phdi
# 91           NPL        Nepal      diff_hdi_phdi
# 92           NPL        Nepal      diff_hdi_phdi
# ..           ...          ...                ...
# 397          NPL        Nepal              hdi_m
# 398          NPL        Nepal              hdi_m
# 399          NPL        Nepal              hdi_m
# 400          NPL        Nepal           hdi_rank
# 903          NPL        Nepal  rankdiff_hdi_phdi
#
#                     indicator_name index_id  \
# 88   Difference from HDI value (%)     PHDI
# 89   Difference from HDI value (%)     PHDI
# 90   Difference from HDI value (%)     PHDI
# 91   Difference from HDI value (%)     PHDI
# 92   Difference from HDI value (%)     PHDI
# ..                             ...      ...
# 397                       HDI male      GDI
# ...

# %%
print(npl_data.columns)
# Out:
# Index(['country_code', 'country_name', 'indicator_id', 'indicator_name',
#        'index_id', 'index_name', 'value', 'year'],
#       dtype='object')

# %%
print(npl_data['indicator_name'].unique())
# Out:
# ['#indicator+name'
#  'Adolescent Birth Rate (births per 1,000 women ages 15-19)' 'Assets (%)'
#  'Child mortality (%)'
#  'Carbon dioxide emissions per capita (production) (tonnes)'
#  'Coefficient of human inequality' 'Cooking fuel (%)'
#  'Difference from HDI value (%)' 'Drinking water (%)' 'Electricity (%)'
#  'Expected Years of Schooling (years)'
#  'Expected Years of Schooling, female (years)'
#  'Expected Years of Schooling, male (years)' 'GDI Group' 'GII Rank'
#  'Gross National Income Per Capita, female (2021 PPP$)'
#  'Gross National Income Per Capita, male (2021 PPP$)'
#  'Gross National Income Per Capita (2021 PPP$)' 'HDI female' 'HDI male'
#  'HDI Rank' 'Housing (%)' 'Inequality in eduation' 'Inequality in income'
#  'Inequality in life expectancy' 'Life Expectancy at Birth (years)'
#  'Life Expectancy at Birth, female (years)'
#  'Life Expectancy at Birth, male (years)'
#  'Labour force participation rate, female (% ages 15 and older)'
# ...

# %%
# basic plots learning

npl_data['year'].iloc[10:21].hist()
# Out:
# <Axes: >
